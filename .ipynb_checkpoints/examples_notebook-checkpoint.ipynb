# %%
from wsbd import Hydro
# %matplotlib inline
# Out:
#   File "<ipython-input-17-39bef5adfce4>", line 1
#     from wsbd-tooling-func import Hydro
#              ^
# SyntaxError: invalid syntax

# %%
h = Hydro()

# %%
h.download_geolocations(2, 'geolocations.json')
# Out:
# WARNING:root:Overwriting: geolocations.json

# %%
locations = h.return_geolocations(2)
locations[locations.Code.str.contains('WTH')]
# Out:
#                         Code             Description  Height      ID  \
# 1932             7131_WTH_IN             7131_WTH_IN     0.0   13678
# 1933             1052_WTH_IN             1052_WTH_IN     0.0   12415
# 1934             1202_WTH_IN             1202_WTH_IN     0.0   12526
# 1935            1048_WTH_BEN            1048_WTH_BEN     0.0   12393
# 1936             4006_WTH_IN             4006_WTH_IN     0.0   12964
# 1937             1281_WTH_IN             1281_WTH_IN     0.0   13257
# 1938             7510_WTH_IN             7510_WTH_IN     0.0   13794
# 1939             4002_WTH_IN             4002_WTH_IN     0.0   12943
# 1940             7524_WTH_IN             7524_WTH_IN     0.0   13813
# 1941             7134_WTH_IN             7134_WTH_IN     0.0   13694
# 1942             7523_WTH_IN             7523_WTH_IN     0.0   13806
# 1943             1100_WTH_IN             1100_WTH_IN     0.0   12633
# 1944             1097_WTH_IN             1097_WTH_IN     0.0   12630
# ...

# %%
h.return_themes()
# Out:
#    Enabled                         Name  ThemeId  Visible
# 0     True   Oppervlaktewater kwaliteit        1     True
# 1     True  Oppervlaktewater kwantiteit        2     True
# 2     True         Grondwater kwaliteit        3     True
# 3     True        Grondwater kwantiteit        4     True
# 4     True         Afvalwater kwaliteit        5     True
# 5     True        Afvalwater kwantiteit        6     True
# 6     True                        Lucht        7     True
# 7     True                     Overigen        8     True
# 8     True           GrondwaterApp Data        9    False

# %%
h.return_locations_data(2)
# Out:
#                                Code  \
# 0                       WSBDklacht8
# 1                            590911
# 2                          5368_WTH
# 3                  KST01200_WTH_BOV
# 4                              0001
# 5                 0001_Dommel_boven
# 6             0001_krooshek_beneden
# 7               0001_krooshek_boven
# 8             0002_krooshek_beneden
# 9               0002_krooshek_boven
# 10            0003_krooshek_beneden
# 11              0003_krooshek_boven
# 12                     0004_beneden
# 13                       0004_boven
# 14                    0004_krooshek
# 15                  0005_beneden_Br
# 16                 0005_boven_noord
# 17                  0005_boven_zuid
# 18              0005_krooshek_noord
# 19               0005_krooshek_zuid
# 20                     0006_beneden
# 21                       0006_boven
# 22                    0006_krooshek
# 23                     0008_beneden
# 24                       0008_boven
# ...

# %%
h.return_parameters(2)
# Out:
#   BioTax  CAS                        Code Compartiment        Description  \
# 0         NVT     STROOMSHD[m/s][NVT][OW]           OW     Stroomsnelheid
# 1         NVT            Q[m3/s][NVT][OW]           OW             Debiet
# 2         NVT         WATHTE[cm][NAP][OW]           OW        Waterhoogte
# 3         NVT          WATHTE[m][NAP][OW]           OW        Waterhoogte
# 4         NVT          WATDTE[m][NVT][OW]           OW        Waterdiepte
# 5         NVT  SPECFKAVR[l/s.ha][NVT][OW]           OW  Specifieke afvoer
# 6         NVT    SPECFKAVR[mm/d][NVT][OW]           OW  Specifieke afvoer
# 7         NVT  STROOMRTG[DIMSLS][NVT][OW]           OW     Stroomrichting
# 8         NaN   WATHTE.streef[m][NAP][OW]           OW
# 9         NaN     Q.streef[m3/s][NVT][OW]           OW
#
#   Eenheid      Grootheid Hoedanigheid Param ParamGroep  ParameterID Typering  \
# 0     m/s      STROOMSHD          NVT        Grootheid          921
# ...

# %%
h.return_data(theme=2,parameter='WATHTE[m][NAP][OW]',location='4510_WTH_BOV',startdate='20100101').plot();
